# %% [markdown]
# # WFSimN - waveform generator for nVeto

# %% [markdown]
# Before run this notebook, please type `make`.

# %%
import numpy as np
import matplotlib.pyplot as plt
import wfsimn
import logging
logging.basicConfig(level='INFO')

# %matplotlib inline

# %%
man = wfsimn.manager()
# if need, set filenames with a path
# man.average_pulse_file_name = ''
# man.mc_file_name = ''
# Out:
# INFO:wfsimn.core:Manager Initialize Ver. 1.0.0 - trial 0

# %%
gen = man.generator()
# Out:
# INFO:wfsimn.generator:Generator Initialize
# INFO:wfsimn.generator:#of events in TTree:10000

# %%
man.wfs = gen.generate_by_mc()
# Out:
# 100%|██████████| 10000/10000 [00:53<00:00, 187.57it/s]

# %%
# %%time
man.save_pickle('wfs.dat')
# Out:
# CPU times: user 869 ms, sys: 1.43 s, total: 2.3 s
# Wall time: 2.36 s

# %%
man.load_pickle('wfs.dat')

# %%
wfs = man.wfs
print('list of waveforms', len(wfs))
print('shape of array in each event', wfs[0].shape)
# 500 timebin (each 2ns) * 120 PMTs
# Out:
# list of waveforms 10000
# shape of array in each event (500, 120)

# %%
vis = man.event_visualizer(eventid=33)

# %%
vis.show_sum_pulse()

# %%
vis.show_pulse(pmtid=0)

# %%
vis.show_map(timebin=30)
